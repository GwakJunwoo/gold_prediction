# %%
from abc import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import statsmodels as sm
import xlwings as xw
import openpyxl
from fredapi import Fred
from datetime import datetime, timedelta
from tqdm import tqdm
import time
import investpy as inv
import sqlite3

class DataMachine(metaclass=ABCMeta):
    def __init__(self):
        self._contents = dict()
        self._startDate = "2000-01-01"
        self._endDate = datetime.now().strftime('%Y-%m-%d')
        self._apiKey = None
        self._dataFrame = None

    @abstractmethod
    def parser(self):
        pass

    @property
    def contents(self):
        return self._contents

    @contents.setter
    def contents(self, value):
        self._contents = value

class FRED(DataMachine):
    """
    ------------------------------------
    FRED 메크로 데이터 크롤링 클래스

                 T10Y    T2Y
    2020-01-01    2.5    1.5
    2020-01-02    2.4    1.3
    2020-01-02    2.3    1.5
    
    Variables:
        apiKey: str, Fred api 사용을 위한 Personal Api Key
        contents: dict, {'사용자 지정 이름': 'FRED 코드'}
        dataFrame: Pandas DataFrame, 데이터 저장 객체
    ------------------------------------
    """
    def __init__(self, apiKey, contents, dataFrame=None):
        super().__init__()
        self._apiKey = apiKey
        self._frd = Fred(api_key=apiKey)
        self.contents(contents)

        if dataFrame != None:
            self._dataFrame = dataFrame

        self.parser()

    def parser(self):
        key = [key for key in self._contents.keys()]
        value = [value for value in self._contents.values()]

        # update
        if self._dataFrame != None:
            tmpFrame = pd.DataFrame()
            lastUpdate = datetime.strftime(self._dataFrame.index[-1]+timedelta(days=1),'%Y-%m-%d')
            for i in tqdm(range(len(value)), desc='Update'):
                tmpFrame[key[i]] = self._frd.get_series(value[i], lastUpdate, self._endDate)
            self._dataFrame = pd.concat([self._dataFrame, tmpFrame])

        #parsing
        else:
            for i in tqdm(range(len(value)), desc='Crawling'):
                self._dataFrame[key[i]] = self._frd.get_series(value[i], self._startDate, self._endDate)

    @property
    def dataFrame(self):
        return self._dataFrame

class KRX(DataMachine):
    """
    ------------------------------------
    KRX 국내 상장 주식, 채권 OHLCV 크롤링 클래스

                  Open   High   Low  Close   Volume
    2020-01-01      1     2      3     4       5
    2020-01-02      1     2      3     4       5
    2020-01-03      1     2      3     4       5
    
    Variables:
        contents: dict, {'사용자 지정 이름': '기업 코드'}
        dataFrame: Pandas DataFrame, 데이터 저장 객체
    ------------------------------------
    """
    def __init__(self, contents, dataFrame=None):
        super().__init__()
        self.contents(contents)

        if dataFrame != None:
            self._dataFrame = dataFrame

    def parser(self):
        key = [key for key in self._contents.keys()]
        value = [value for value in self._contents.values()]

        # update
        if self._dataFrame != None:
            tmpFrame = pd.DataFrame()
            lastUpdate = datetime.strftime(self._dataFrame.index[-1]+timedelta(days=1),'%Y-%m-%d')
            for i in tqdm(range(len(value)), desc='Update'):
                tmpFrame[key[i]] = self._frd.get_series(value[i], lastUpdate, self._endDate)
            self._dataFrame = pd.concat([self._dataFrame, tmpFrame])

        #parsing
        else:
            for i in tqdm(range(len(value)), desc='Crawling'):
                self._dataFrame[key[i]] = self._frd.get_series(value[i], self._startDate, self._endDate)

    @property
    def dataFrame(self):
        return self._dataFrame

# %%
from pykrx import stock, bond

stock.get_index_ohlcv_by_date('20000101','20221218','1001')
# Out:
# 코스피              시가       고가       저가       종가        거래량           거래대금  \
# 날짜
# 2000-01-04  1028.33  1066.18  1016.59  1059.04  195898660  3771013000000
# 2000-01-05  1006.87  1047.70   984.05   986.31  257696170  4798126000000
# 2000-01-06  1013.95  1014.90   953.50   960.79  203523570  3726898000000
# 2000-01-07   949.17   970.16   930.84   948.65  215664150  3696686000000
# 2000-01-10   979.67   994.94   965.02   987.24  240175480  3815037000000
# ...             ...      ...      ...      ...        ...            ...
# 2022-12-12  2373.58  2381.87  2368.47  2373.02  499224684  5822259612423
# 2022-12-13  2385.05  2388.27  2364.87  2372.40  447565388  6659361034224
# 2022-12-14  2380.81  2400.18  2379.44  2399.25  409799402  5724107192073
# 2022-12-15  2383.83  2392.11  2360.95  2360.97  375386441  6134217159398
# 2022-12-16  2329.75  2360.44  2326.83  2360.02  414172006  7206180401653
#
# 코스피                   상장시가총액
# 날짜
# 2000-01-04                 0
# 2000-01-05                 0
# 2000-01-06                 0
# 2000-01-07                 0
# 2000-01-10                 0
# ...                      ...
# 2022-12-12  1875700660827307
# 2022-12-13  1874838727660788
# 2022-12-14  1895655040773681
# 2022-12-15  1865842784271843
# 2022-12-16  1865107455187511
#
# [5669 rows x 7 columns]

# %%
a = stock.get_index_ohlcv_by_date('20000101','20221218','1001')['종가']
a
# Out:
# 날짜
# 2000-01-04    1059.04
# 2000-01-05     986.31
# 2000-01-06     960.79
# 2000-01-07     948.65
# 2000-01-10     987.24
#                ...
# 2022-12-12    2373.02
# 2022-12-13    2372.40
# 2022-12-14    2399.25
# 2022-12-15    2360.97
# 2022-12-16    2360.02
# Name: 종가, Length: 5669, dtype: float64

# %%
import FinanceDataReader as fdr
fdr.DataReader('GC=F','2018-01-01', '2018-03-30')['Adj Close']
# Out:
# Date
# 2018-01-02    1313.699951
# 2018-01-03    1316.199951
# 2018-01-04    1319.400024
# 2018-01-05    1320.300049
# 2018-01-08    1318.599976
#                  ...
# 2018-03-23    1349.300049
# 2018-03-26    1354.400024
# 2018-03-27    1341.300049
# 2018-03-28    1324.199951
# 2018-03-29    1322.800049
# Name: Adj Close, Length: 61, dtype: float64

# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web

start_time = dt.datetime(2000, 1, 1)
end_time = dt.datetime(2022, 2, 1)
df = web.DataReader('MEI_CTRY_WEIGHTS', 'oecd', start_time, end_time)

print(df.shape)
df.info()
df.head()
# Out:
# (21, 82)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21 entries, 2000-01-01 to 2020-01-01
# Data columns (total 82 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   (Greece, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  1   (Greece, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  2   (Switzerland, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)      21 non-null     float64
#  3   (Switzerland, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)      21 non-null     float64
#  4   (Czech Republic, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)   21 non-null     float64
#  5   (Czech Republic, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)   21 non-null     float64
#  6   (Australia, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)        21 non-null     float64
#  7   (Australia, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)        21 non-null     float64
#  8   (Netherlands, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)      21 non-null     float64
#  9   (Netherlands, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)      21 non-null     float64
#  10  (Poland, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  11  (Poland, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  12  (Luxembourg, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)       21 non-null     float64
#  13  (Luxembourg, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)       21 non-null     float64
#  14  (New Zealand, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)      21 non-null     float64
#  15  (New Zealand, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)      21 non-null     float64
#  16  (Iceland, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          0 non-null      float64
#  17  (Iceland, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  18  (France, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  19  (France, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  20  (United Kingdom, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)   21 non-null     float64
#  21  (United Kingdom, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)   21 non-null     float64
#  22  (Japan, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  23  (Japan, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  24  (OECD - Total, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)     21 non-null     float64
#  25  (OECD - Total, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)     21 non-null     float64
#  26  (Belgium, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  27  (Belgium, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  28  (Israel, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  29  (Israel, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  30  (Slovak Republic, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)  21 non-null     float64
#  31  (Slovak Republic, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)  21 non-null     float64
#  32  (United States, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)    21 non-null     float64
#  33  (United States, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)    21 non-null     float64
#  34  (Ireland, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  35  (Ireland, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  36  (Mexico, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  37  (Mexico, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  38  (Spain, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  39  (Spain, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  40  (G7, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)               21 non-null     float64
#  41  (G7, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)               21 non-null     float64
#  42  (Estonia, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  43  (Estonia, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  44  (Hungary, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  45  (Hungary, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  46  (Denmark, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  47  (Denmark, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  48  (OECD - Europe, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)    21 non-null     float64
#  49  (OECD - Europe, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)    21 non-null     float64
#  50  (Norway, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  51  (Norway, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  52  (Canada, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  53  (Canada, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  54  (Austria, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  55  (Austria, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  56  (Korea, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  57  (Korea, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  58  (Portugal, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)         21 non-null     float64
#  59  (Portugal, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)         21 non-null     float64
#  60  (Italy, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  61  (Italy, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  62  (Türkiye, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  63  (Türkiye, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  64  (Slovenia, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)         21 non-null     float64
#  65  (Slovenia, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)         21 non-null     float64
#  66  (Germany, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  67  (Germany, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  68  (Finland, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  69  (Finland, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)          21 non-null     float64
#  70  (Sweden, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  71  (Sweden, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  72  (Chile, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            0 non-null      float64
#  73  (Chile, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)            21 non-null     float64
#  74  (Latvia, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  75  (Latvia, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)           21 non-null     float64
#  76  (Lithuania, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)        21 non-null     float64
#  77  (Lithuania, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)        21 non-null     float64
#  78  (Colombia, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)         21 non-null     float64
#  79  (Colombia, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)         21 non-null     float64
#  80  (Costa Rica, PPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)       21 non-null     float64
#  81  (Costa Rica, CPI country weights in percentage of OECD Total, in percentage of OECD Total, Annual)       21 non-null     float64
# dtypes: float64(82)
# memory usage: 13.6 KB
# Country                                                  Greece  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.719193
# 2001-01-01                                             0.747185
# 2002-01-01                                             0.779334
# 2003-01-01                                             0.795389
# 2004-01-01                                             0.801133
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.744075
# 2001-01-01                                             0.773662
# 2002-01-01                                             0.813800
# 2003-01-01                                             0.812828
# 2004-01-01                                             0.811302
#
# Country                                             Switzerland  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.898936
# 2001-01-01                                             0.897400
# 2002-01-01                                             0.891217
# 2003-01-01                                             0.865850
# 2004-01-01                                             0.852714
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.823315
# 2001-01-01                                             0.820695
# 2002-01-01                                             0.811645
# 2003-01-01                                             0.791145
# 2004-01-01                                             0.779116
#
# Country                                          Czech Republic  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.567801
# 2001-01-01                                             0.590974
# 2002-01-01                                             0.588295
# 2003-01-01                                             0.606634
# 2004-01-01                                             0.613069
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.453541
# 2001-01-01                                             0.470074
# 2002-01-01                                             0.459063
# 2003-01-01                                             0.471653
# 2004-01-01                                             0.472032
#
# Country                                               Australia  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             1.838130
# 2001-01-01                                             1.871561
# 2002-01-01                                             1.898395
# 2003-01-01                                             1.943790
# 2004-01-01                                             1.945083
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             1.724117
# 2001-01-01                                             1.716521
# 2002-01-01                                             1.745560
# 2003-01-01                                             1.748197
# 2004-01-01                                             1.775367
#
# Country                                             Netherlands  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             1.730930
# 2001-01-01                                             1.747754
# 2002-01-01                                             1.758328
# 2003-01-01                                             1.687636
# 2004-01-01                                             1.674649
#
# Country                                                          ...  \
# Country weights CPI country weights in percentage of OECD Total  ...
# Measure                             in percentage of OECD Total  ...
# Frequency                                                Annual  ...
# Time                                                             ...
# 2000-01-01                                             1.487708  ...
# 2001-01-01                                             1.473084  ...
# 2002-01-01                                             1.489761  ...
# 2003-01-01                                             1.413120  ...
# 2004-01-01                                             1.398430  ...
#
# Country                                                   Chile  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                                  NaN
# 2001-01-01                                                  NaN
# 2002-01-01                                                  NaN
# 2003-01-01                                                  NaN
# 2004-01-01                                                  NaN
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.419814
# 2001-01-01                                             0.417201
# 2002-01-01                                             0.416122
# 2003-01-01                                             0.426609
# 2004-01-01                                             0.447028
#
# Country                                                  Latvia  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.064912
# 2001-01-01                                             0.069392
# 2002-01-01                                             0.073614
# 2003-01-01                                             0.077080
# 2004-01-01                                             0.079814
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.060601
# 2001-01-01                                             0.063891
# 2002-01-01                                             0.067343
# 2003-01-01                                             0.070183
# 2004-01-01                                             0.074016
#
# Country                                               Lithuania  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.100797
# 2001-01-01                                             0.107511
# 2002-01-01                                             0.114061
# 2003-01-01                                             0.125528
# 2004-01-01                                             0.126391
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.100532
# 2001-01-01                                             0.104118
# 2002-01-01                                             0.109694
# 2003-01-01                                             0.121837
# 2004-01-01                                             0.126592
#
# Country                                                Colombia  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.896242
# 2001-01-01                                             0.896420
# 2002-01-01                                             0.898752
# 2003-01-01                                             0.916689
# 2004-01-01                                             0.935070
#
# Country                                                          \
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.965766
# 2001-01-01                                             0.982731
# 2002-01-01                                             0.997795
# 2003-01-01                                             1.015396
# 2004-01-01                                             1.013443
#
# Country                                              Costa Rica  \
# Country weights PPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.109418
# 2001-01-01                                             0.111353
# 2002-01-01                                             0.112561
# 2003-01-01                                             0.115171
# 2004-01-01                                             0.116369
#
# Country
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             0.113779
# 2001-01-01                                             0.112683
# 2002-01-01                                             0.118147
# 2003-01-01                                             0.124375
# 2004-01-01                                             0.126293
#
# [5 rows x 82 columns]

# %%
country = "Japan"
df_japan_total = df[country]
df_japan_total.head()
# Out:
# Country weights PPI country weights in percentage of OECD Total  \
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             11.80374
# 2001-01-01                                             11.66288
# 2002-01-01                                             11.53052
# 2003-01-01                                             11.43365
# 2004-01-01                                             11.31362
#
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             9.457836
# 2001-01-01                                             9.408059
# 2002-01-01                                             9.486904
# 2003-01-01                                             9.516927
# 2004-01-01                                             9.353314

# %%
pd.DataFrame(df_japan_total)
# Out:
# Country weights PPI country weights in percentage of OECD Total  \
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                            11.803740
# 2001-01-01                                            11.662880
# 2002-01-01                                            11.530520
# 2003-01-01                                            11.433650
# 2004-01-01                                            11.313620
# 2005-01-01                                            11.193900
# 2006-01-01                                            10.909380
# 2007-01-01                                            10.764940
# 2008-01-01                                            10.489330
# 2009-01-01                                            10.190440
# 2010-01-01                                            10.268520
# 2011-01-01                                            10.047700
# 2012-01-01                                            10.091400
# 2013-01-01                                            10.134100
# 2014-01-01                                             9.811858
# 2015-01-01                                             9.790606
# 2016-01-01                                             9.330060
# 2017-01-01                                             9.115320
# 2018-01-01                                             8.853744
# 2019-01-01                                             8.649795
# 2020-01-01                                             8.723820
#
# Country weights CPI country weights in percentage of OECD Total
# Measure                             in percentage of OECD Total
# Frequency                                                Annual
# Time
# 2000-01-01                                             9.457836
# 2001-01-01                                             9.408059
# 2002-01-01                                             9.486904
# 2003-01-01                                             9.516927
# 2004-01-01                                             9.353314
# 2005-01-01                                             9.413013
# 2006-01-01                                             9.332022
# 2007-01-01                                             9.174304
# 2008-01-01                                             9.095966
# 2009-01-01                                             9.194797
# 2010-01-01                                             9.175289
# 2011-01-01                                             9.041295
# 2012-01-01                                             9.194049
# 2013-01-01                                             9.617176
# 2014-01-01                                             9.220440
# 2015-01-01                                             9.023671
# 2016-01-01                                             8.185545
# 2017-01-01                                             7.934593
# 2018-01-01                                             7.766842
# 2019-01-01                                             7.490762
# 2020-01-01                                             7.527193
